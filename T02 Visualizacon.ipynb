# %% [markdown]
# Tarea SANTIAGO CHAVARRIA MINAKATA 17/08/2005

# %%
#iMPORTACION DE LIBRERIAS
import matplotlib.pyplot as plt
import sympy as sp 
import numpy as np

# %% [markdown]
# 1. Graficar las siguientes funciones f(x). Determina el dominio a partir de la función:

# %% [markdown]
# $$ f(x)=x^2-4x+2 $$

# %%
x=np.linspace(-500,500,500)
y=x**2-4*x+2
plt.plot(x,y)

# %% [markdown]
# $$ f(x)= sin(3x) $$

# %%
x=np.linspace(-100,100,100)
y=np.sin(3*x)
plt.plot(x,y)

# %% [markdown]
# $$ f(x)=e^(2x)-3 $$

# %%
x=np.linspace(-1000,1000,1000)
y=np.exp(2*x)-3
plt.plot(x,y)
# Out:
# C:\Users\helio\AppData\Local\Temp\ipykernel_18112\164175792.py:2: RuntimeWarning: overflow encountered in exp
#   y=np.exp(2*x)-3

# %% [markdown]
# $$ f(x) = \sqrt{x^2 - 4} $$

# %%
x=np.linspace(-500,500,500)
y=np.sqrt(x**2 - 4)
plt.plot(x,y)
# Out:
# C:\Users\helio\AppData\Local\Temp\ipykernel_18112\3086548010.py:2: RuntimeWarning: invalid value encountered in sqrt
#   y=np.sqrt(x**2 - 4)

# %% [markdown]
# $$ f(x) = cos(x+\pi/4) $$

# %%
x=np.linspace(-10,10,10)
y=np.cos(x+np.pi/4)
plt.plot(x,y)

# %% [markdown]
# ![Imagen de WhatsApp 2024-08-29 a las 12.32.21_cfbdd684.jpg](attachment:82a6edf3-71d7-42d4-a9c0-97ae589e9648.jpg)

# %% [markdown]
# 2. Graficar los siguientes grupos de funciones:

# %% [markdown]
# GRUPO 1
# $$ y1= 2x + 1 $$
# $$ y2= -x + 4 $$
# $$ y3= x^2  $$

# %%
import matplotlib.pyplot as plt
import sympy as sp 
import numpy as np 
x = np.linspace(-10,10,100)
y1=2*x+1
y2=-x+4
y3=x**2
plt.plot(x,y1,color="r")
plt.plot(x,y2,color='g')
plt.plot(x,y3,color='b')

# %%
import matplotlib.pyplot as plt
import sympy as sp 
import numpy as np 
x = np.linspace(-5,5,50)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,color="r")
plt.plot(x,y2,color='g')

# %% [markdown]
# ![Imagen de WhatsApp 2024-08-29 a las 12.32.20_b04ef3ce.jpg](attachment:3b964316-4a70-4dad-ad27-57404c20464c.jpg)

# %% [markdown]
# 3. Crea una función que cree una gráfica y dibuje 'k' líneas de $$ f(x)= sin(ax) $$La función recibe:
# x1: valor inicial de 'x'
# x2: valor final de 'x'
# n: cantidad de puntos del vector 'x'
# a: valor inicial de image.png
# b: valor final de image.png
# k: cantidad de líneas
# Usar el la variable opcional de "label" y el comando de legend para saber qué línea pertenece a qué image.png.

# %%
import matplotlib.pyplot as plt
import sympy as sp 
import numpy as np
x1=0
x2=2*np.pi
n=1000
x=np.linspace(x1,x2,n)
al = np.linspace(1,3,3)
for alpha in al:
    y = np.sin(alpha * x)
    plt.plot(x, y)
plt.show()

# %% [markdown]
# ![Imagen de WhatsApp 2024-08-29 a las 12.32.17_8ee682db.jpg](attachment:de11fa18-5945-431b-a827-f07c5c92e273.jpg)
