# %% [markdown]
# Santiago Chavarria Minakata  22 de AGO de 2024 **A 03 python**

# %% [markdown]
# 2.  Crea las siguientes estructuras usando numpy:
# Encuentra el resultado de AB

# %%
import numpy as np 
A =np.array([[1,2],
             [3,4]])
b = np.array([[2],
              [4]])

# %%
mult = A@b
mult
# Out:
# array([[10],
#        [22]])

# %% [markdown]
# ![Imagen de WhatsApp 2024-08-23 a las 09.26.44_2b6cb220.jpg](attachment:5e84c61b-a635-46b6-9618-190e5a56e491.jpg)

# %% [markdown]
# 1. Toma el archivo datosCT.xlsx y
#
# CALCULAR UTILIDAD

# %%
import pandas as pd
datos= pd.read_excel("datosCT.xlsx")
datos
# Out:
#     Unnamed: 0  Ingreso  Gasto
# 0        Enero     1340   1880
# 1      Febrero     2590   3130
# 2        Marzo     3570   2140
# 3        Abril     4450   3370
# 4         Mayo     1330   2990
# 5        Junio     1610   1970
# 6        Julio     1500   2230
# 7       Agosto     2270   1240
# 8   Septiembre     1910   1470
# 9      Octubre     2120   2280
# 10   Noviembre     3950   1870
# 11   Diciembre     1380   3140

# %%
datos["Utilidad"] = datos["Ingreso"] - (datos["Gasto"])
datos
# Out:
#     Unnamed: 0  Ingreso  Gasto  Utilidad
# 0        Enero     1340   1880      -540
# 1      Febrero     2590   3130      -540
# 2        Marzo     3570   2140      1430
# 3        Abril     4450   3370      1080
# 4         Mayo     1330   2990     -1660
# 5        Junio     1610   1970      -360
# 6        Julio     1500   2230      -730
# 7       Agosto     2270   1240      1030
# 8   Septiembre     1910   1470       440
# 9      Octubre     2120   2280      -160
# 10   Noviembre     3950   1870      2080
# 11   Diciembre     1380   3140     -1760

# %% [markdown]
# INGRESOS TOTALES

# %%
H=sum(datos["Ingreso"])
H
# Out:
# 28020

# %% [markdown]
# PROMEDIOS DE GASTOS EN MESES NEGATIVOS

# %%
NEG=datos[datos["Utilidad"]<0]
np.mean(NEG["Gasto"])
# Out:
# 2517.1428571428573

# %% [markdown]
# ![Imagen de WhatsApp 2024-08-23 a las 09.26.42_1e8db63b.jpg](attachment:c2a61444-20c6-41cc-98b5-2c376828e28c.jpg)
